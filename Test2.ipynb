# %%
# CASO Python Faker
# pip install Faker
from faker import Faker
dumy = Faker()
# Get Profile
print(dumy.profile())
# Get random sentence
print(dumy.sentence())
# Get a random name
print(dumy.name())
# Get a random address
print(dumy.address())
# Get a random phone number
print(dumy.phone_number())
# Get a random email address
print(dumy.email())
# Get a random company name
print(dumy.company())
# Get a random city
print(dumy.city())
# Get a random state
print(dumy.state())
# Get a random zip code
print(dumy.zipcode())
# Out:
# {'job': 'Local government officer', 'company': 'Edwards LLC', 'ssn': '339-16-6337', 'residence': '2149 Kevin Estates Apt. 238\nNew Karen, PA 04828', 'current_location': (Decimal('38.8866535'), Decimal('169.775692')), 'blood_group': 'O+', 'website': ['http://www.schmidt.com/'], 'username': 'ldalton', 'name': 'Michael Park', 'sex': 'M', 'address': 'USNV Irwin\nFPO AP 14868', 'mail': 'plopez@yahoo.com', 'birthdate': datetime.date(2011, 11, 14)}
# Mention yeah article education enjoy.
# Michael Ross
# 32363 Douglas Estate Apt. 307
# West Jennifer, NY 62897
# 912-466-6013x76611
# dwhite@example.org
# Johnston PLC
# Martineztown
# Rhode Island
# 63515
